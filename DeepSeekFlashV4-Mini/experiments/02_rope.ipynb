# %% [markdown]
# # RoPE
#
# Apply rotary embeddings to a random Q tensor.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.rope import apply_rope
q = torch.randn(1, 4, 8, 16)
print(apply_rope(q).shape)
