# %% [markdown]
# # Training
#
# One tiny training step.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model import DeepSeekFlashV4Mini, preset
from training.losses import lm_loss
m=DeepSeekFlashV4Mini(preset('demo'))
x=torch.randint(0,m.cfg.vocab_size,(4,16))
y=torch.randint(0,m.cfg.vocab_size,(4,16))
logits,_=m(x,trace=False)
loss=lm_loss(logits,y)
loss.backward()
print(float(loss))
