# %% [markdown]
# # MoE
#
# Forward a MoE block and inspect log.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.moe import MoE
m = MoE(64,8,1,2,128)
x = torch.randn(2,8,64)
log=[]
y=m(x, tokens=torch.randint(0,64,(2,8)), log=log)
print(y.shape, log)
