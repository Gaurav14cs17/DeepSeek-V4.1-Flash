# %% [markdown]
# # Attention
#
# Sliding-window vs causal attention shapes.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.attention import SlidingWindowAttention, CausalSelfAttention
x = torch.randn(2, 12, 64)
print(SlidingWindowAttention(64,4,16,8)(x).shape)
print(CausalSelfAttention(64,4,16)(x).shape)
