# %% [markdown]
# # CSA / HCA / MLA
#
# Compressed and latent attention variants.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.mla import CSA, HCA, MLA
x = torch.randn(1, 16, 64)
print('CSA', CSA(64,4,16)(x).shape)
print('HCA', HCA(64,4,16,compress=8)(x).shape)
print('MLA', MLA(64,4,16)(x).shape)
