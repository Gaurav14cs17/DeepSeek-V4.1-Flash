# %% [markdown]
# # KV cache accounting
#
# Estimate V4 KV / replay cost.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
from model import preset
from optimization.kv_cache import estimate_kv
s=estimate_kv(preset('pc'), 64)
print(s.summary())
print('\n'.join(s.notes))
