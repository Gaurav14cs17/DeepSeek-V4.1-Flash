# %% [markdown]
# # Router
#
# Top-k routing indices.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.router import Router
r=Router(64,8,2)
v,i=r(torch.randn(10,64))
print(v.shape, i[:3])
