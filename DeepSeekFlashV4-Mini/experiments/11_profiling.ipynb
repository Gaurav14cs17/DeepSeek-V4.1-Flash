# %% [markdown]
# # Profiling
#
# Time a forward pass.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model import DeepSeekFlashV4Mini, preset
from optimization.profiling import Timer
m=DeepSeekFlashV4Mini(preset('demo')); x=torch.randint(0,m.cfg.vocab_size,(2,32))
t=Timer()
with t.track('forward'):
    m(x,trace=False)
print(t.report())
