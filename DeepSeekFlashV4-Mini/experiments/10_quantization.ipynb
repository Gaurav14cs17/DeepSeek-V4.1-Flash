# %% [markdown]
# # Quantization
#
# Fake quantize a tensor.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from optimization.quantization import fake_quantize, mxfp4_sim
x=torch.randn(4,8)
print(fake_quantize(x,8).std(), mxfp4_sim(x).std())
