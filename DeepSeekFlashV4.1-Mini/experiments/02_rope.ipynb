# %% [markdown]
# # RoPE
#
# Apply rotary embeddings.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.rope import apply_rope
print(apply_rope(torch.randn(1,4,8,16)).shape)
