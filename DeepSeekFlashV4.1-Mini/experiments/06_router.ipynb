# %% [markdown]
# # Router
#
# Router top-k.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.router import Router
print(Router(64,8,2)(torch.randn(10,64))[1].shape)
