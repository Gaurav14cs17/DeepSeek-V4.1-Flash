# %% [markdown]
# # Quantization
#
# FP4-ish sim.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from optimization.quantization import mxfp4_sim
print(mxfp4_sim(torch.randn(8,8)).shape)
