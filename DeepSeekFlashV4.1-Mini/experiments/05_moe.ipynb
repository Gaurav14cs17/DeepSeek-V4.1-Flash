# %% [markdown]
# # MoE
#
# MoE forward.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.moe import MoE
m=MoE(64,8,1,2,128)
print(m(torch.randn(2,8,64)).shape)
