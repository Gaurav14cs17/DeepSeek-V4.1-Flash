# %% [markdown]
# # KV / Bounded Replay
#
# V4.1 KV notes.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
from model import preset
from optimization.kv_cache import estimate_kv
print(estimate_kv(preset('pc'), 64).summary())
