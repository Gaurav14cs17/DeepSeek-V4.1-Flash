# %% [markdown]
# # V4 → V4.1 changes
#
# CED, Single-Pass mHC, Engram, Bounded Replay.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
from model import preset
cfg=preset('pc')
print('enc/dec', cfg.n_encoder_layers, cfg.n_decoder_layers)
print('fp4 main KV', cfg.use_fp4_main_kv)
