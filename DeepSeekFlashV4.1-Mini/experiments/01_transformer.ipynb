# %% [markdown]
# # V4.1 Transformer / CED
#
# Build V4.1 Mini and run prefill.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model import DeepSeekFlashV41Mini, preset
m = DeepSeekFlashV41Mini(preset('demo'))
x = torch.randint(0, m.cfg.vocab_size, (1, 16))
logits, info = m(x)
print('logits', logits.shape)
print('\n'.join(info['log'][:15]))
