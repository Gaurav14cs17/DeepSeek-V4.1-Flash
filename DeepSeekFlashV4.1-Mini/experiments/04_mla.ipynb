# %% [markdown]
# # CSA2
#
# CSA2 Full mode toy forward.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.mla import CSA2
m=CSA2(64,4,16,compress=2,topk=4,mode='full')
print(m(torch.randn(1,16,64)).shape)
