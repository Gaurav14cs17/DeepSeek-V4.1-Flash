# %% [markdown]
# # Profiling
#
# Time forward.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model import DeepSeekFlashV41Mini, preset
from optimization.profiling import Timer
m=DeepSeekFlashV41Mini(preset('demo')); t=Timer()
with t.track('forward'):
    m(torch.randint(0,m.cfg.vocab_size,(2,32)),trace=False)
print(t.report())
