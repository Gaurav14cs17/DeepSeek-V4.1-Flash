# %% [markdown]
# # Shared experts
#
# Shared experts.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))
import torch
from model.shared_experts import SharedExperts
print(SharedExperts(64,1,128)(torch.randn(5,64)).shape)
