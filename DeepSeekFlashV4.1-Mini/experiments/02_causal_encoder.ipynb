# %% [markdown]
# # Experiment — 02 Causal Encoder
#
# ## 1. Research question
#
# Deferred until earlier stages unlock (see `docs/progress.md`).
#
# ## 2. Paper reference
#
# TBD when this stage starts.
#
# ## 12. Production difference
#
# Tiny Mini ≠ production Flash.

# %%
print('DEFERRED — open docs/progress.md')
